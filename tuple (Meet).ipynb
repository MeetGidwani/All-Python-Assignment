# %%
numbers =(10,20,30,40,50,60,70,80,90)
print("Tuple:",numbers)
print("4th elementfrom first:",numbers[3])
print("4th elementfrom last:",numbers[-4])
# Out:
# Tuple: (10, 20, 30, 40, 50, 60, 70, 80, 90)
# 4th elementfrom first: 40
# 4th elementfrom last: 60

# %%
numbers =(10,20,30,40,50)
element = int(input("Enter element to search:"))
if element in numbers:
    print("element exist in the tuple")
else:
    print("Element does not exist in the tuple")
# Out:
# Enter element to search: 5
# Element does not exist in the tuple

# %%
numbers_list =[10,20,30,40,50]
numbers_tuple = tuple(numbers_list)
print("List:",numbers_list)
print("Tuple:",numbers_tuple)
# Out:
# List: [10, 20, 30, 40, 50]
# Tuple: (10, 20, 30, 40, 50)

# %%
numbers =(10,20,30,40,50)
element = int(input("Enter element:"))
if element in numbers:
    print("Index of Element:", numbers.index(element))
else:
    print("Element not found")
# Out:
# Enter element: 30
# Index of Element: 2

# %%
numbers =[(10,20,30),(40,50,60),(70,80,90)]
new_list=[]
for tup in numbers:
    new_tup =tup[:-1]+(100,)
    new_list.append(new_tup)
print("Original List:",numbers)
print("Updated List:",new_list)
# Out:
# Original List: [(10, 20, 30), (40, 50, 60), (70, 80, 90)]
# Updated List: [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

# %%
numbers =(25,10,45,5,60,30)
maximum=max(numbers)
minimum =min(numbers)
print("Tuple:",numbers)
print("Maximum element:",maximum)
print("Minimum element:",minimum)
# Out:
# Tuple: (25, 10, 45, 5, 60, 30)
# Maximum element: 60
# Minimum element: 5

# %%
numbers =(10,20,30,40,50)
new_tuple = (numbers[-1],)+ numbers[1:-1]+numbers[0],)
print("Original Tuple:",numbers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 numbers =(10,20,30,40,50)
# ----> 2 new_tuple = (numbers[-1],)+ numbers[1:-1]+numbers[0],
#
# TypeError: can only concatenate tuple (not "int") to tuple
