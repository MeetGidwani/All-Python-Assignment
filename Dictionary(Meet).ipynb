# %%
my_dict = {0: 10 , 1: 20}
my_dict[2] = 30
print("Dictionary:", my_dict)
# Out:
# Dictionary: {0: 10, 1: 20, 2: 30}

# %%
dic1 = {1: 10,2: 20}
dic2 = {3: 30,4: 40}
dic3 = {5: 50,6: 60}
new_dict ={}
new_dict.update(dic1)
new_dict.update(dic2)
new_dict.update(dic3)
print("New Dictionary:",new_dict)
# Out:
# New Dictionary: {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
my_dict = {101:"aMIT",102:"rAHUL",103:"Priya"}
key = int(input("Enter key in Search:"))
if key in my_dict:
    print("key exists in the Dictionary")
else:
    print("Key does not exixt in the Dictionary")
# Out:
# Enter key in Search: 103
# key exists in the Dictionary

# %%
my_dict ={
    101:"Amit",
    102:"rahul",
    103:"Priya"
}


print("Keys:")
for key in my_dict:
    print(key)
print("\nValues")
for values in my_dict.values():
    print(values)
print("\nKeys and values:")
for key,value in my_dict.items():
    print(key,value)
# Out:
# Keys:
# 101
# 102
# 103
#
# Values
# Amit
# rahul
# Priya
#
# Keys and values:
# 101 Amit
# 102 rahul
# 103 Priya

# %%
my_dict ={}
for i in range(1,16):
    my_dict[i]=i**2
    print(my_dict)
# Out:
# {1: 1}
# {1: 1, 2: 4}
# {1: 1, 2: 4, 3: 9}
# {1: 1, 2: 4, 3: 9, 4: 16}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
my_dict = {"a":10,"b":20,"c":30,"d":40}
total=0
for value in my_dict.values():
    total= total+value
print("Sum of values:",total)
# Out:
# Sum of values: 100

# %%
my_dict = { 101:"amit", 102:"amit", 103:"priya", 104:"Sneha", 105:"Neha"}
print("Original Student Information")
print(my_dict)
my_dict[106]="Rohan"
print("\nAfter Adding Student:")
print(my_dict)
del my_dict[103]
print("\nAfter Deleting Student:")
print(my_dict)
print("\nStudent Information:")
for roll_no,name in my_dict.items():
    print("Roll No:",roll_no,"Name:",name)
# Out:
# Original Student Information
# {101: 'amit', 102: 'amit', 103: 'priya', 104: 'Sneha', 105: 'Neha'}
#
# After Adding Student:
# {101: 'amit', 102: 'amit', 103: 'priya', 104: 'Sneha', 105: 'Neha', 106: 'Rohan'}
#
# After Deleting Student:
# {101: 'amit', 102: 'amit', 104: 'Sneha', 105: 'Neha', 106: 'Rohan'}
#
# Student Information:
# Roll No: 101 Name: amit
# Roll No: 102 Name: amit
# Roll No: 104 Name: Sneha
# Roll No: 105 Name: Neha
# Roll No: 106 Name: Rohan

# %%
list1 = ["name","panel","rollno"]
list2 = ["ABC","B",34]
my_dict = dict(zip(list1, list2))
print("Dictionary:",my_dict)
# Out:
# Dictionary: {'name': 'ABC', 'panel': 'B', 'rollno': 34}

# %%
my_dict = { "name":"ABC", "panel":"B", "rollno":34 }
keys_list = list(my_dict.keys())
values_list = list(my_dict.values())
print("KeysList:",keys_list)
print("Values List:", values_list)
# Out:
# KeysList: ['name', 'panel', 'rollno']
# Values List: ['ABC', 'B', 34]

# %%
my_dict = { "marks1":23, "marks2":123, "marks":43, "marks4":13 , "marks5":39 }
total = sum(my_dict.values())
mean= total/len(my_dict)
print("Mean of all values:", mean )
# Out:
# Mean of all values: 48.2

# %%
my_dict={
    "name":"ABC",
    "panel":"B",
    "rollno":34,
    "marks":[65,87,67,94]
}
sorted_dict = sorted(my_dict)
print("Sorted keys:", sorted_dict)
# Out:
# Sorted keys: ['marks', 'name', 'panel', 'rollno']

# %%
students = {
    "Amit":85,
    " Rahul":92,
    "Priya":78,
    "Sneha":95,
    "Neha":88
}
highest_student = max(students, key=students.get)
print("Student with Highest Marks:", highest_student)
print("Highest Marks:", student[highest_student])
# Out:
# Student with Highest Marks: Sneha
# Highest Marks: 95

# %%
numbers =[10,20,10,30,20,10,40,30]
frequency ={}
for num in numbers:
    if num in frequency:
        frequency[num]=frequency[num]+1
    else:
        frequency[num]=1
    print("Frequency of Elements:",frequency)
# Out:
# Frequency of Elements: {10: 1}
# Frequency of Elements: {10: 1, 20: 1}
# Frequency of Elements: {10: 2, 20: 1}
# Frequency of Elements: {10: 2, 20: 1, 30: 1}
# Frequency of Elements: {10: 2, 20: 2, 30: 1}
# Frequency of Elements: {10: 3, 20: 2, 30: 1}
# Frequency of Elements: {10: 3, 20: 2, 30: 1, 40: 1}
# Frequency of Elements: {10: 3, 20: 2, 30: 2, 40: 1}

# %%
my_dict ={
    "Amit":85,
    "RAhul":72,
    "Priya":95,
    "Sneha":80
}
sorted_dict = dict(sorted(my_dict.items(),key=lambda item:item[1]))   #hole line same   ,reverse=True    for Decending order 
print("Dictionary sorted by Values:",sorted_dict)
# Out:
# Dictionary sorted by Values: {'RAhul': 72, 'Sneha': 80, 'Amit': 85, 'Priya': 95}
